# %% [markdown]
# ##Grants

# %%
# %sql
GRANT SELECT ON TABLE catalog_au.bronze.circuits TO `ejemplo04@gmail.com`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG catalog_au TO `ejemplo04@gmail.com`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA catalog_au.bronze TO `ejemplo04@gmail.com`;

GRANT USE SCHEMA ON SCHEMA catalog_au.bronze TO `DEs`;

# %%
# %sql
GRANT CREATE TABLE ON SCHEMA catalog_dev.bronze TO `ejemplo04@gmail.com`;
